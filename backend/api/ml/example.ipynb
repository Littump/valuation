# %% [markdown]
#  ## перевод массива InMemoryUploadedFile в массив PIL

# %%
from PIL import Image
from io import BytesIO

def imuf_array_to_pil_array(arr):    
    res = []
    for file in arr:
        file_data = file.read()
        image_data = BytesIO(file_data)
        res.append(Image.open(image_data))
    return res

# %% [markdown]
# ## Пример создания экземпляра модели

# %%
from model import PriceEstimator
model = PriceEstimator('models', device='cpu')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Vitya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Vitya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Пример использования get_repair

# %%
import os
from PIL import Image
imgs = []
for i in os.listdir('A:\\datasets\\real_estate_finodays_2023\\test_photos\\3'):
    imgs.append(Image.open('A:\\datasets\\real_estate_finodays_2023\\test_photos\\3\\'+i))

# %%
model.get_repair(imgs)
# Out:
# {'interior_style': 2.4452078,
#  'interior_qual': 1.8593098,
#  'embeddings': array([-1.56870317e+00,  6.90021157e-01,  3.45137596e-01,  5.66595018e-01,
#          6.74043179e-01, -1.19477674e-01, -2.35460758e+00, -1.40918386e+00,
#         -1.45172310e+00, -4.47958291e-01,  9.76785421e-01, -7.10129559e-01,
#          4.75908488e-01,  1.08901672e-01,  8.96734238e-01, -1.74109578e+00,
#          4.68700022e-01, -1.74208188e+00, -1.56538272e+00, -1.61479688e+00,
#         -1.94760096e+00, -7.20060095e-02,  8.18561316e-01,  7.34283209e-01,
#         -1.41776383e+00, -2.34046555e+00, -1.08826745e+00, -1.36838543e+00,
#         -8.46281767e-01, -3.31099343e+00,  8.21863234e-01,  7.45305479e-01,
#         -2.14331794e+00, -1.90244603e+00, -1.03091991e+00, -2.16293857e-01,
#          7.54136682e-01,  5.01451731e-01, -2.27788067e+00, -1.74667156e+00,
#         -1.68387842e+00,  1.57890562e-02, -2.38073325e+00,  7.80037940e-01,
#          7.58751333e-01,  6.72325313e-01, -1.59936714e+00, -2.62661791e+00,
#         -4.63433385e-01, -6.29346132e-01, -2.27809143e+00,  1.24939755e-01,
#         -1.36587703e+00,  9.86528456e-01,  8.27991426e-01, -1.69516265e+00,
#         -1.52797401e+00, -2.57892418e+00,  8.12338829e-01,  8.67380679e-01,
#          3.95635217e-01, -2.22925401e+00, -1.73202062e+00, -1.81539118e+00,
#         -2.48217511e+00,  4.75278497e-01, -2.11933517e+00, -2.58978724e+00,
#         -1.82901144e+00,  4.97995168e-01, -3.28508299e-03, -5.29160440e-01,
#         -2.42088103e+00, -1.46646988e+00, -2.49752188e+00, -1.07600260e+00,
#         -2.12001872e+00,  7.95322835e-01, -1.70030713e+00, -1.24400246e+00,
#         -1.24501145e+00,  7.52374113e-01,  7.40309536e-01, -5.96381783e-01,
#          4.33683217e-01,  7.94410944e-01, -7.82202482e-01, -3.89204696e-02,
#         -1.49393034e+00,  8.12104762e-01,  1.37335762e-01,  7.30378330e-02,
#          5.31928599e-01,  9.60157037e-01, -1.02266169e+00,  7.59635031e-01,
#         -2.46818566e+00,  4.84982103e-01, -1.67040062e+00, -8.45139474e-02],
#        dtype=float32)}

# %% [markdown]
# ## Пример обработки запроса

# %%
text='''Код объекта: 392199.
Готовый арендный бизнес или для проживания.
Апартаменты под ключ со всеми удобствами. Двухэтажные Апартаменты со свежим косметическим ремонтом на территории Новой Москвы! Центральное отопление, электричество и все коммуникации. 
Закрытая, ухоженная территория.
Общая площадь 32 м2. 

Отличный вариант для проживания, инвестиции и сдачи в аренду (доход 27 тыс. руб/мес).
Вся инфраструктура в шаговой доступности: Школа, Детский сад, Поликлиника, храм, магазины, шикарный большой парк. 
До метро Саларьево 20 мин на автобусе.
ПОМОЩЬ В ПОЛУЧЕНИИ ИПОТЕКИ.'''

model.predict({'adress':'Москва, ТАО (Троицкий), м. Рассказовка, пос. Первомайское, улица Центральная, 28',
                'object_type': '2',
                'text': text,
                'house_material': 'blc',            
                'cnt_rooms': 1,
                'floor': 4,
                'area': 32.0,
                'has_lift': 0,
                'parking_type': '0',
                'photos': imgs
               })
# Out:
# {'cnt_rooms': 1, 'area': 32.0, 'object_type': 2, 'house_material': 'blc', 'floor': 4, 'has_lift': 0, 'parking_type': '0', 'Площадь всего': 3532.0, 'Год постройки': 2021, 'Число этажей': 3, 'Аварийный': 'Нет', 'Количество квартир': 60, 'Площадь жилых в м2': 2703.4, 'Площадь нежилых в м2': 0.0, 'Культурное наследие': 'Нет', 'Класс энергетической эффективности': 'Нет информации', 'Количество подъездов': 2, 'Количество лифтов': 'Нет информации', 'Приспособления для маломобильных людей': 'Да', 'Водоотведение': 'Центральное', 'Газоснабжение': 'Центральное', 'Горячее водоснабжение': 'Индивидуальный котел', 'Холодное водоснабжение': 'Централизованная (от городской сети)', 'Теплоснабжение': 'Квартирное отопление (котел)', 'Электроснабжение': 'Нет информации', 'Несущие стены': 'Пенобетонные блоки', 'Фундамент': 'Плитный (сплошной)', 'Перекрытия': 'Перекрытия из сборных и монолитных сплошных плит', 'x_coord': -29.605760752393746, 'y_coord': -44.12346916415271, 'dist_to_center': 53.25984267033212, 'nearest_metro': 'Щелковская', 'nearest_metro_dist': 53.63927613120202, 'second_nearest_metro': 'Первомайская', 'second_nearest_metro_dist': 54.58748369503306, 'pca_photo_0': -13.10046293791823, 'pca_photo_1': 0.11208071993134441, 'pca_photo_2': 3.208805826947516, 'pca_photo_3': -0.5044932648984741, 'pca_photo_4': -0.43668138278912716, 'pca_photo_5': -0.6327769952168738, 'pca_photo_6': -0.1602656778907674, 'pca_photo_7': 0.3128786630002353, 'interior_style': 2.4452078, 'interior_qual': 1.8593098, 'pca_text_0': 0.0511329881607307, 'pca_text_1': 1.7164862594664592, 'pca_text_2': -1.056795627917234, 'pca_text_3': -0.6431055927060549, 'pca_text_4': -0.47415726624157717, 'pca_text_5': 0.5402728193641204, 'pca_text_6': -0.06448230805446162, 'pca_text_7': 0.15549456519933036, 'pca_text_8': 1.2358852548830077, 'pca_text_9': 0.4212111062341529, 'pca_text_10': -0.33012506692285926, 'pca_text_11': -0.8751963203839641, 'pca_text_12': -0.6705277982090315, 'pca_text_13': 0.017170267392584565, 'pca_text_14': -0.2528301909045041, 'pca_text_15': 0.9299341143464003, 'pca_text_16': -0.8104001962607816, 'pca_text_17': -0.4078095578136858, 'pca_text_18': 0.23911720256654467, 'pca_text_19': 0.119076446085148, 'продуктовый магазин': 0, 'достопримечательность': 0, 'кафе': 0, 'аптека': 0, 'детский сад': 0, 'школа': 0, 'фитнес-клуб': 0, 'поликлиника': 0, 'тц': 0, 'кинотеатр': 0, 'infro_cnt': 0}
# 0    6.414555e+06
# Name: area, dtype: float64
