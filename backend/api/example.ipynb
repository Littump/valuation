# %% [markdown]
#  ## перевод массива InMemoryUploadedFile в массив PIL

# %%
from PIL import Image
from io import BytesIO

def imuf_array_to_pil_array(arr):    
    res = []
    for file in arr:
        file_data = file.read()
        image_data = BytesIO(file_data)
        res.append(Image.open(image_data))
    return res

# %% [markdown]
# ## Пример создания экземпляра модели

# %%
# !pip3 install dill
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.7 MB/s eta 0:00:00 0:00:01
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import os
with open('/Users/yakimov/Dev/hack/valuation/backend/api/ml/models/cols_order_for_msc_head_without_photo_and_zhkh.txt', 'r') as file:
    for line in file:
        ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ------------------
# absl-py                       2.0.0
# appnope                       0.1.3
# asgiref                       3.7.2
# asttokens                     2.4.0
# astunparse                    1.6.3
# backcall                      0.2.0
# cachetools                    5.3.1
# catboost                      1.2.2
# certifi                       2023.7.22
# cffi                          1.16.0
# charset-normalizer            3.3.0
# click                         8.1.7
# comm                          0.1.4
# contourpy                     1.1.1
# cryptography                  41.0.4
# cycler                        0.12.1
# DAWG-Python                   0.7.2
# debugpy                       1.8.0
# decorator                     5.1.1
# defusedxml                    0.8.0rc2
# dill                          0.3.7
# Django                        3.2
# django-cors-headers           4.3.0
# ...

# %%
import dill
from model import PriceEstimator

model1 = PriceEstimator('models')

# with open('price_estimator.pkl', 'wb') as f:
#     dill.dump(model, f)
# Out:
# /Users/yakimov/Dev/hack/valuation/.venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [nltk_data] Downloading package punkt to /Users/yakimov/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yakimov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open('price_estimator.pkl', 'rb') as f:
    model = dill.load(f)

# %% [markdown]
# ## Пример использования get_repair

# %%
import os
from PIL import Image
imgs = []
for i in os.listdir('A:\\datasets\\real_estate_finodays_2023\\test_photos\\3'):
    imgs.append(Image.open('A:\\datasets\\real_estate_finodays_2023\\test_photos\\3\\'+i))

# %%
model1.get_repair("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yakimov/Dev/hack/valuation/backend/api/ml/example.ipynb Ячейка 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/yakimov/Dev/hack/valuation/backend/api/ml/example.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> model1.get_repair("")
#
# NameError: name 'model1' is not defined

# %% [markdown]
# ## Пример обработки запроса

# %%
text='''Код объекта: 392199.
Готовый арендный бизнес или для проживания.
Апартаменты под ключ со всеми удобствами. Двухэтажные Апартаменты со свежим косметическим ремонтом на территории Новой Москвы! Центральное отопление, электричество и все коммуникации. 
Закрытая, ухоженная территория.
Общая площадь 32 м2. 

Отличный вариант для проживания, инвестиции и сдачи в аренду (доход 27 тыс. руб/мес).
Вся инфраструктура в шаговой доступности: Школа, Детский сад, Поликлиника, храм, магазины, шикарный большой парк. 
До метро Саларьево 20 мин на автобусе.
ПОМОЩЬ В ПОЛУЧЕНИИ ИПОТЕКИ.'''

model1.predict({'adress':'Москва, ТАО (Троицкий), м. Рассказовка, пос. Первомайское, улица Центральная, 28',
                'object_type': '2',
                'text': text,
                'house_material': 'blc',            
                'cnt_rooms': 1,
                'floor': 4,
                'area': 32.0,
                'has_lift': 0,
                'parking_type': '0',
                'photos': (2, 2)
               })
# Out:
# {'cnt_rooms': 1, 'area': 32.0, 'object_type': 2, 'house_material': 'blc', 'floor': 4, 'has_lift': 0, 'parking_type': '0', 'x_coord': -23.931455770290235, 'y_coord': -28.876085901114926, 'dist_to_center': 37.56492810924016, 'nearest_metro': 'Щелковская', 'nearest_metro_dist': 53.81939905303999, 'second_nearest_metro': 'Первомайская', 'second_nearest_metro_dist': 54.77211745440852, 'interior_style': 2, 'interior_qual': 2, 'pca_text_0': 0.051132988160730725, 'pca_text_1': 1.7164862594664594, 'pca_text_2': -1.0567956279172341, 'pca_text_3': -0.6431055927060549, 'pca_text_4': -0.4741572662415771, 'pca_text_5': 0.5402728193641205, 'pca_text_6': -0.06448230805446165, 'pca_text_7': 0.15549456519933036, 'pca_text_8': 1.2358852548830077, 'pca_text_9': 0.42121110623415303, 'pca_text_10': -0.3301250669228593, 'pca_text_11': -0.8751963203839639, 'pca_text_12': -0.6705277982090316, 'pca_text_13': 0.01717026739258462, 'pca_text_14': -0.2528301909045041, 'pca_text_15': 0.9299341143464003, 'pca_text_
# ...

# %%
model.df_zhkh
# Out:
#        index                                              Адрес  \
# 0          0                 Москва, 1-й Амбулаторный проезд, 2
# 1          1              Москва, 1-й Амбулаторный проезд, 5 к1
# 2          2              Москва, 1-й Амбулаторный проезд, 5 к2
# 3          3              Москва, 1-й Амбулаторный проезд, 7 к3
# 4          4              Москва, 1-й Амбулаторный проезд, 7 кА
# ...      ...                                                ...
# 75291   6871  Нижегородская область, Нижний Новгород, Ясная ...
# 75292   6872  Нижегородская область, Нижний Новгород, Ясная ...
# 75293   6873  Нижегородская область, Нижний Новгород, Ясная ...
# 75294   6874  Нижегородская область, Нижний Новгород, Ясная ...
# 75295   6875  Нижегородская область, Нижний Новгород, Ясная ...
#
#                                                   Ссылка  Площадь всего  \
# 0             https://dom.mingkh.ru/moskva/moskva/916691        10046.4
# ...

# %%
model.heads
# Out:
# {'msc_head_full': <catboost.core.CatBoostRegressor at 0x2b68a88e0>,
#  'msc_head_without_photo': <catboost.core.CatBoostRegressor at 0x2b68a8ac0>,
#  'msc_head_without_photo_and_zhkh': <catboost.core.CatBoostRegressor at 0x2b68a8b50>,
#  'msc_head_without_zhkh': <catboost.core.CatBoostRegressor at 0x2b68b3880>}
